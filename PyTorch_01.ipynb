# %%
import Pytorch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-73657d25721c> in <module>
# ----> 1 import Pytorch
#
# ModuleNotFoundError: No module named 'Pytorch'
